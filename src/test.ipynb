# %%
lista = [1, 2, 3]

[x * 2 for x in lista]
# Out:
# [2, 4, 6]

# %%
from tools.translate import translate
# Out:
# 2025-11-27 11:57:20.190 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-27 11:57:20.372
# ...
#   command:
#
#     streamlit run /home/toxfu/miniforge3/envs/bai/lib/python3.13/site-packages/ipykernel_launcher.py [ARGUMENTS]
# 2025-11-27 11:57:20.372 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-27 11:57:20.373 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-27 11:57:20.373 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-27 11:57:20.874 Thread 'Thread-4': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-27 11:57:20.875 Thread 'Thread-4': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# ...

# %%
text = ["the policy so it has extracted the documents and again finally you will see the output after the agent has done its job so the state has completed again if we the guardrails I mean since we did not set any input and output guardrails those are empty had we set probably it would have said if the guardrails success fail etc etc all right so that's", "he second agent so as you can see building racks also becoming easier and easier so we can just upload all our knowledge base to the vector store and it does all the chunking etc under the hood now to the agent all we need to do is simply", "supply this file search tool with the vector store id okay so the even building the agents sorry building the rag agents is becoming easier by the day and the final the most interesting one is the computer use okay all right it's much more involved so we don't go into the code in detail because this is the first time", "I'm using computer use and I'm also trying to understand all the nitty-gritty details but under the hood it uses this playwright the playwright it's a web automation testing type of framework okay"]

# %%
texts, audio_durations, translate_segments_path = translate("tmp", text)

# %%
texts
# Out:
# ['la política así que ha extraído los documentos y otra vez finalmente verá la salida después de que el agente ha hecho su trabajo así que el estado ha terminado de nuevo si nosotros los barandillas quiero decir desde que no hemos establecido ninguna entrada y salida barandillas que están vacíos si hubiéramos establecido probablemente habría dicho si los barandillas éxito falla etc etc así que está bien',
#  'El segundo agente para que puedas ver que las estanterías de construcción también se vuelven más y más fáciles para que podamos simplemente subir toda nuestra base de conocimientos a la tienda vectorial y hace todo el chunking etc bajo el capó ahora al agente todo lo que tenemos que hacer es simplemente',
# ...
